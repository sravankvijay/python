# %%
#write a python program to print all the colors from set 1 not contain in set 2

a=set(input("enter the colors seperated by commas:").split(","))
b=set(input("enter the colors seperated by commas: ").split(","))
c=a-b
print("colors from set a not contain in color b",c)
# Out:
# enter the colors seperated by commas:blue,black,red
# enter the colors seperated by commas: white,orange,red
# colors from set a not contain in color b {'black', 'blue'}

# %%
#write a program to print all colors from set1 and set2

a=set(input("enter the colors seperated by commas:").split(","))
b=set(input("enter the colors seperated by commas: ").split(","))
c=a|b
print("color set from a and b:",c)
# Out:
# enter the colors seperated by commas:blue,red
# enter the colors seperated by commas: black
# color set from a and b: {'red', 'black', 'blue'}
