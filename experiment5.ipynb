# %%
#tupple
#3rd element and 3rd element from last

a=input("enter the numbers seperated by commas:")
b=a.split(",")
print("3rd element:",b[2])
print("3rd element from last:",b[-3])
# Out:
# enter the numbers seperated by commas: 10,20,30,40,50,560
# 3rd element: 30
# 3rd element from last: 40

# %%
a=input("enter the numbers seperated by commas:")
b=a.split(",")
b=tuple(int(x)for x in b)
print("tupple:",b)
print("Average:",sum(b)/len(b))
# Out:
# enter the numbers seperated by commas: 10,20,30
# tupple: (10, 20, 30)
# Average: 20.0
