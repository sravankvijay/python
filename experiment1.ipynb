# %%
#area of circle
import math
a=int(input('enter a number'))
area=math.pi*a*a
print('area=',area)
# Out:
# enter a number2
# area= 12.566370614359172

# %%
#compute vale of n+nn+nnn
a=input('enter the number')
aa=a+a
aaa=a+a+a
sum=int(a)+int(aa)+int(aaa)
print(a,"+",aa,"+",aaa,'=',sum)
# Out:
# enter the number5
# 5 + 55 + 555 = 615

# %%
#find biggest of three
a=int(input('enter 1st number'))
b=int(input('enter 2nd number'))
c=int(input('enter 3rd number'))
print('biggest=',max(a,b,c))
# Out:
# enter 1st number100
# enter 2nd number500
# enter 3rd number3
# biggest= 500
